# %%
import os
import time

# %%
import nltk

# %% [markdown]
# we are learning nltk module in NLP

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
example_input = "NLP is especially useful in fully or partially automating tasks like customer support, data entry and document handling. For example, NLP-powered chatbots can handle routine customer queries, freeing up human agents for more complex issues"

# %%
example_input = example_input.lower()
print(example_input)
# Out:
# nlp is especially useful in fully or partially automating tasks like customer support, data entry and document handling. for example, nlp-powered chatbots can handle routine customer queries, freeing up human agents for more complex issues

# %%
import re

clean_text = re.sub(r"[^a-zA-Z0-9 ]", "", example_input)
print(clean_text)
# Out:
# nlp is especially useful in fully or partially automating tasks like customer support data entry and document handling for example nlppowered chatbots can handle routine customer queries freeing up human agents for more complex issues

# %%
word_text = word_tokenize(clean_text)
print(word_text)
# Out:
# ['nlp', 'is', 'especially', 'useful', 'in', 'fully', 'or', 'partially', 'automating', 'tasks', 'like', 'customer', 'support', 'data', 'entry', 'and', 'document', 'handling', 'for', 'example', 'nlppowered', 'chatbots', 'can', 'handle', 'routine', 'customer', 'queries', 'freeing', 'up', 'human', 'agents', 'for', 'more', 'complex', 'issues']

# %%
sent_tokenize(example_input)
# Out:
# ['NLP is especially useful in fully or partially automating tasks like customer support, data entry and document handling.',
#  'For example, NLP-powered chatbots can handle routine customer queries, freeing up human agents for more complex issues']

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("spanish"))
print(stop_words)
# Out:
# {'otra', 'estaríais', 'tendrían', 'fueron', 'unos', 'sin', 'estabas', 'sentido', 'están', 'tuvieron', 'tanto', 'habríais', 'estarás', 'fueras', 'otras', 'serás', 'hemos', 'tuya', 'sea', 'estuviéramos', 'teníais', 'como', 'estos', 'nada', 'soy', 'míos', 'seáis', 'sean', 'su', 'tendrás', 'tendría', 'estás', 'él', 'siente', 'esos', 'tiene', 'estuvieseis', 'habría', 'estaban', 'ti', 'tendré', 'tuviéramos', 'tuyos', 'hubieron', 'mis', 'estarías', 'un', 'tendrán', 'estuve', 'tuvieras', 'tenido', 'entre', 'tengo', 'vosotras', 'hubierais', 'esas', 'fueseis', 'estadas', 'mucho', 'ha', 'tuvimos', 'hubieses', 'tuviste', 'tenía', 'estuviste', 'estuviese', 'habrá', 'te', 'estará', 'una', 'tened', 'tenga', 'habremos', 'y', 'estábamos', 'poco', 'al', 'pero', 'han', 'hayáis', 'estuvieras', 'he', 'fuéramos', 'fuiste', 'será', 'serías', 'donde', 'sobre', 'éramos', 'fue', 'hayamos', 'está', 'estarán', 'hubiesen', 'nuestra', 'todo', 'sentida', 'era', 'para', 'estoy', 'hubo', 'muchos', 'otros', 'estén', 
# ...

# %%
cleaned_words = []
for i in word_text:
    if i not in stop_words:
        cleaned_words.append(i)

print(word_text)

print(cleaned_words)
# Out:
# ['nlp', 'is', 'especially', 'useful', 'in', 'fully', 'or', 'partially', 'automating', 'tasks', 'like', 'customer', 'support', 'data', 'entry', 'and', 'document', 'handling', 'for', 'example', 'nlppowered', 'chatbots', 'can', 'handle', 'routine', 'customer', 'queries', 'freeing', 'up', 'human', 'agents', 'for', 'more', 'complex', 'issues']
# ['nlp', 'especially', 'useful', 'fully', 'partially', 'automating', 'tasks', 'like', 'customer', 'support', 'data', 'entry', 'document', 'handling', 'example', 'nlppowered', 'chatbots', 'handle', 'routine', 'customer', 'queries', 'freeing', 'human', 'agents', 'complex', 'issues']

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer

porter = PorterStemmer()
snowball = SnowballStemmer(language='english')
lanc = LancasterStemmer()

# %%
print(porter.stem('amazing'))
print(porter.stem('amazement'))
print(porter.stem('amaze'))
print(porter.stem('amazed'))
print(porter.stem('amazon'))
print(porter.stem('nation'))
print(porter.stem('premonition'))

# Comparison between Porter and Snowball
print(porter.stem('loudly'))
print(snowball.stem('loudly'))

# Comparison between Snowball and Lancaster
print(porter.stem('salty'))
print(snowball.stem('salty'))
# Out:
# amaz
# amaz
# amaz
# amaz
# amazon
# nation
# premonit
# loudli
# loud
# salti
# salti
